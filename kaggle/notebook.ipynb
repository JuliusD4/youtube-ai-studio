# %% [markdown]
# # 🎬 AI YouTube Studio - Générateur Automatique de Vidéos YouTube (0 €)
#
# **Bienvenue !** Vous n'avez besoin d'écrire aucun script : entrez simplement le **titre de votre vidéo** dans la cellule ci-dessous.
#
# L'IA Directrice Artistique s'occupe de tout :
# 1. 🧠 **Scénario sur-mesure** : Analyse du sujet et écriture d'un script captivant pour YouTube (pas de template figé !).
# 2. 🎙️ **Voix française HD** : Synthèse vocale naturelle avec Chatterbox V3.
# 3. 👤 **Présentateur Avatar** : Un créateur qui parle face caméra avec synchronisation labiale (MuseTalk).
# 4. 🎞️ **Montage dynamique YouTube** : Alternance entre plans larges *Facecam* et plans *Picture-in-Picture* (le B-roll en grand et l'avatar en bas à droite).
# 5. 🎵 **Habillage sonore pro** : Musique d'ambiance Lo-Fi + effets de transition (*whoosh*) + sous-titres Whisper.

# %%
# ==============================================================================
# 👉 ÉTAPE UNIQUE : ENTREZ LE TITRE / SUJET DE VOTRE VIDÉO ICI
# ==============================================================================

VIDEO_TITLE = "Comment l'Intelligence Artificielle va bouleverser notre quotidien en 2026"

print(f"🎬 Titre configuré : {VIDEO_TITLE}")
print("Cliquez sur 'Run All' pour lancer la création !")

# %%
# 2. Chargement immédiat du code source (Zéro blocage)
import os
import sys
import shutil
import zipfile

REPO_DIR = '/kaggle/working/youtube-ai-studio'
DATASET_DIR = '/kaggle/input/youtube-ai-studio-code'

os.makedirs(REPO_DIR, exist_ok=True)

# Cas 1 : Code disponible instantanément via le dataset Kaggle monté
if os.path.exists(DATASET_DIR):
    print('✅ Chargement instantané depuis le dataset Kaggle...')
    for item in os.listdir(DATASET_DIR):
        s = os.path.join(DATASET_DIR, item)
        if item.endswith('.zip'):
            target_folder = os.path.join(REPO_DIR, item[:-4])
            os.makedirs(target_folder, exist_ok=True)
            with zipfile.ZipFile(s, 'r') as zip_ref:
                zip_ref.extractall(target_folder)
        elif os.path.isdir(s):
            d = os.path.join(REPO_DIR, item)
            shutil.copytree(s, d, dirs_exist_ok=True)
        else:
            d = os.path.join(REPO_DIR, item)
            shutil.copy2(s, d)
    print('✅ Code prêt dans', REPO_DIR)
else:
    # Cas 2 : Synchronisation GitHub sécurisée avec timeout et sans prompt bloquant
    print('Tentative de synchronisation GitHub...')
    os.environ['GIT_TERMINAL_PROMPT'] = '0'
    try:
        from kaggle_secrets import UserSecretsClient
        user_secrets = UserSecretsClient()
        gh_token = user_secrets.get_secret('GITHUB_TOKEN')
    except Exception:
        gh_token = os.environ.get('GITHUB_TOKEN')

    if gh_token:
        clone_url = f'https://x-access-token:{gh_token}@github.com/JuliusD4/youtube-ai-studio.git'
    else:
        clone_url = 'https://github.com/JuliusD4/youtube-ai-studio.git'

    if not os.path.exists(os.path.join(REPO_DIR, 'src')):
        # !git clone --depth 1 {clone_url} {REPO_DIR}
    else:
        # !cd {REPO_DIR} && git pull

# %cd {REPO_DIR}
if REPO_DIR not in sys.path:
    sys.path.insert(0, REPO_DIR)

# %%
# 3. Installation et configuration de l'environnement GPU
# !python kaggle/setup_environment.py

# %%
# 4. Configuration des clés et variables d'environnement
import os
try:
    from kaggle_secrets import UserSecretsClient
    user_secrets = UserSecretsClient()
    os.environ['PEXELS_API_KEY'] = user_secrets.get_secret('PEXELS_API_KEY')
    print('✅ Clé PEXELS_API_KEY chargée depuis les Secrets Kaggle.')
except Exception:
    if not os.environ.get('PEXELS_API_KEY'):
        os.environ['PEXELS_API_KEY'] = 'jJBpVYSofawrLICuNmdoTzesZE3BG3L2oHgHxKn1JBjTs6BF47G55eIa'
        print('ℹ️ Clé PEXELS_API_KEY par défaut initialisée.')

# %%
# 5. Production de la vidéo par l'IA Directrice Artistique
from src.pipeline import YouTubeVideoPipeline

pipeline = YouTubeVideoPipeline()
result = pipeline.create_video_from_title(
    video_title=VIDEO_TITLE,
    output_filename="video_youtube_finale.mp4",
)

print('Résultat de la production :')
print(f"Vidéo finale prête : {result['final_video']}")

# %%
# 6. Visionner la vidéo finale directement dans Kaggle
from IPython.display import Video, display
display(Video(result['final_video'], embed=True, width=720))
